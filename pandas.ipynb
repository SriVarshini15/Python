# %% [markdown]
# <a href="https://colab.research.google.com/github/SriVarshini15/Python/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PANDAS
# import

# %%
import pandas as pd

# %% [markdown]
# #DATAFRAME

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C'],index=['I','II','III'])
df
# Out:
#      A  B  C
# I    1  2  3
# II   4  5  6
# III  7  8  9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index
# Out:
# Index(['I', 'II', 'III'], dtype='object')

# %%
df['A']
# Out:
# I      1
# II     4
# III    7
# Name: A, dtype: int64

# %%
df.head(1)
# Out:
#    A  B  C
# I  1  2  3

# %%
df.tail(2)
# Out:
#      A  B  C
# II   4  5  6
# III  7  8  9

# %%
df.index.tolist()
# Out:
# ['I', 'II', 'III']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, I to III
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
dff=pd.read_csv('/content/coffee.csv')
dff
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
dff.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
dp=pd.read_parquet('/content/results.parquet')
dp
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...

# %%
olympic = pd.read_excel('/content/olympics-data.xlsx',sheet_name="results")
olympic.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
dff.to_excel
# Out:
# <bound method NDFrame.to_excel of           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35>

# %%
dff.to_parquet()
# Out:
# b'PAR1\x15\x04\x15\x9c\x01\x15\x94\x01L\x15\x0e\x15\x00\x12\x00\x00Np\x06\x00\x00\x00Monday\x07\x00\x00\x00Tuesday\t\x00\x00\x00Wedn\x05\r\x00\x08\x01\x18\x18hursday\x01.\x10Frida\x05\x16DSaturday\x06\x00\x00\x00Sunday\x15\x00\x15\x1c\x15 ,\x15\x1c\x15\x10\x15\x06\x15\x06\x1c6\x00(\tWednesday\x18\x06Friday\x00\x00\x00\x0e4\x02\x00\x00\x00\x1c\x01\x03\x05@"mdk\x03\x15\x04\x15*\x15.L\x15\x04\x15\x00\x12\x00\x00\x15P\x08\x00\x00\x00Espresso\x05\x00\x00\x00Latte\x15\x00\x15\x14\x15\x18,\x15\x1c\x15\x10\x15\x06\x15\x06\x1c6\x00(\x05Latte\x18\x08Espresso\x00\x00\x00\n$\x02\x00\x00\x00\x1c\x01\x01\x05\xaa*\x15\x04\x15p\x15PL\x15\x0e\x15\x00\x12\x00\x008\x04\x19\x00\t\x01\x00\x0f\t\x07\x04\x00\x1e\r\x08\x00\x14\r\x08\x00#\r\x08<(\x00\x00\x00\x00\x00\x00\x00-\x00\x00\x00\x00\x00\x00\x00\x15\x00\x15\x1c\x15 ,\x15\x1c\x15\x10\x15\x06\x15\x06\x1c\x18\x08-\x00\x00\x00\x00\x00\x00\x00\x18\x08\x0f\x00\x00\x00\x00\x00\x00\x00\x16\x00(\x08-\x00\x00\x00\x00\x00\x00\x00\x18\x08\x0f\x00\x00\x00\x00\x00\
# ...

# %% [markdown]
# #ACCESSING DATA

# %%
dff
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
dff.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
dff.tail(10)
# Out:
#           Day Coffee Type  Units Sold
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
dff.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
dff.loc[[2,5,1]]
# Out:
#          Day Coffee Type  Units Sold
# 2    Tuesday    Espresso          30
# 5  Wednesday       Latte          25
# 1     Monday       Latte          15

# %%
dff.loc[[5,7],["Day", "Coffee Type"]]
# Out:
#          Day Coffee Type
# 5  Wednesday       Latte
# 7   Thursday       Latte

# %%
dff.iloc[[5,7],[0,1]]
# Out:
#          Day Coffee Type
# 5  Wednesday       Latte
# 7   Thursday       Latte

# %%
dff.index=dff["Day"]
dff
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25
# Thursday    Thursday    Espresso          40
# Thursday    Thursday       Latte          30
# Friday        Friday    Espresso          45
# Friday        Friday       Latte          35
# Saturday    Saturday    Espresso          45
# Saturday    Saturday       Latte          35
# Sunday        Sunday    Espresso          45
# Sunday        Sunday       Latte          35

# %%
dff.loc["Monday":"Wednesday"]
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25

# %%
dff.loc[1,"Units Sold"]=10
dff
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        25.0
# Monday        Monday       Latte        15.0
# Tuesday      Tuesday    Espresso        30.0
# Tuesday      Tuesday       Latte        20.0
# Wednesday  Wednesday    Espresso        35.0
# Wednesday  Wednesday       Latte        25.0
# Thursday    Thursday    Espresso        40.0
# Thursday    Thursday       Latte        30.0
# Friday        Friday    Espresso        45.0
# Friday        Friday       Latte        35.0
# Saturday    Saturday    Espresso        45.0
# Saturday    Saturday       Latte        35.0
# Sunday        Sunday    Espresso        45.0
# Sunday        Sunday       Latte        35.0
# 1                NaN         NaN        10.0

# %%
dff.loc[1:2,"Units Sold"]=10
dff
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-546def60f9ed> in <cell line: 0>()
# ----> 1 dff.loc[1:2,"Units Sold"]=10
#       2 dff
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     905             maybe_callable = com.apply_if_callable(key, self.obj)
#     906             key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 907         indexer = self._get_setitem_indexer(key)
#     908         self._has_valid_setitem_indexer(key)
#     909
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     772             with suppress(IndexingError):
#     773                 # suppress "Too many indexers"
# --> 774                 return self._convert_tuple(key)
#     775
#     776         if isinstance(key, range):
#
# ...

# %%
#for single value
dff.iat[0,2]
# Out:
# np.float64(25.0)

# %%
#dff.at[0,'Units Sold']
dff.iloc[0]['Units Sold']
# Out:
# np.float64(25.0)

# %%
dff['Day']
# Out:
# Day
# Monday          Monday
# Monday          Monday
# Tuesday        Tuesday
# Tuesday        Tuesday
# Wednesday    Wednesday
# Wednesday    Wednesday
# Thursday      Thursday
# Thursday      Thursday
# Friday          Friday
# Friday          Friday
# Saturday      Saturday
# Saturday      Saturday
# Sunday          Sunday
# Sunday          Sunday
# 1                  NaN
# Name: Day, dtype: object

# %%
dff.Day
# Out:
# Day
# Monday          Monday
# Monday          Monday
# Tuesday        Tuesday
# Tuesday        Tuesday
# Wednesday    Wednesday
# Wednesday    Wednesday
# Thursday      Thursday
# Thursday      Thursday
# Friday          Friday
# Friday          Friday
# Saturday      Saturday
# Saturday      Saturday
# Sunday          Sunday
# Sunday          Sunday
# 1                  NaN
# Name: Day, dtype: object

# %%
dff.sort_values("Units Sold")
# Out:
#                  Day Coffee Type  Units Sold
# Day
# 1                NaN         NaN        10.0
# Monday        Monday       Latte        15.0
# Tuesday      Tuesday       Latte        20.0
# Monday        Monday    Espresso        25.0
# Wednesday  Wednesday       Latte        25.0
# Tuesday      Tuesday    Espresso        30.0
# Thursday    Thursday       Latte        30.0
# Wednesday  Wednesday    Espresso        35.0
# Sunday        Sunday       Latte        35.0
# Friday        Friday       Latte        35.0
# Saturday    Saturday       Latte        35.0
# Thursday    Thursday    Espresso        40.0
# Saturday    Saturday    Espresso        45.0
# Friday        Friday    Espresso        45.0
# Sunday        Sunday    Espresso        45.0

# %%
dff.sort_values("Units Sold",ascending=False)
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Sunday        Sunday    Espresso        45.0
# Saturday    Saturday    Espresso        45.0
# Friday        Friday    Espresso        45.0
# Thursday    Thursday    Espresso        40.0
# Friday        Friday       Latte        35.0
# Wednesday  Wednesday    Espresso        35.0
# Sunday        Sunday       Latte        35.0
# Saturday    Saturday       Latte        35.0
# Tuesday      Tuesday    Espresso        30.0
# Thursday    Thursday       Latte        30.0
# Wednesday  Wednesday       Latte        25.0
# Monday        Monday    Espresso        25.0
# Tuesday      Tuesday       Latte        20.0
# Monday        Monday       Latte        15.0
# 1                NaN         NaN        10.0

# %%
dff.sort_values(["Units Sold","Coffee Type"],ascending=[False,True])
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Friday        Friday    Espresso        45.0
# Saturday    Saturday    Espresso        45.0
# Sunday        Sunday    Espresso        45.0
# Thursday    Thursday    Espresso        40.0
# Wednesday  Wednesday    Espresso        35.0
# Friday        Friday       Latte        35.0
# Saturday    Saturday       Latte        35.0
# Sunday        Sunday       Latte        35.0
# Tuesday      Tuesday    Espresso        30.0
# Thursday    Thursday       Latte        30.0
# Monday        Monday    Espresso        25.0
# Wednesday  Wednesday       Latte        25.0
# Tuesday      Tuesday       Latte        20.0
# Monday        Monday       Latte        15.0
# 1                NaN         NaN        10.0

# %%
for i,j in dff.iterrows():
  print(i)
  print(j)
  print('\n')
# Out:
# Monday
# Day              Monday
# Coffee Type    Espresso
# Units Sold         25.0
# Name: Monday, dtype: object
#
#
# Monday
# Day            Monday
# Coffee Type     Latte
# Units Sold       15.0
# Name: Monday, dtype: object
#
#
# Tuesday
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold         30.0
# Name: Tuesday, dtype: object
#
#
# Tuesday
# Day            Tuesday
# Coffee Type      Latte
# Units Sold        20.0
# Name: Tuesday, dtype: object
#
#
# Wednesday
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold          35.0
# Name: Wednesday, dtype: object
#
#
# Wednesday
# Day            Wednesday
# Coffee Type        Latte
# Units Sold          25.0
# Name: Wednesday, dtype: object
#
#
# Thursday
# Day            Thursday
# Coffee Type    Espresso
# Units Sold         40.0
# Name: Thursday, dtype: object
#
#
# Thursday
# Day            Thursday
# Coffee Type       Latte
# Units Sold         30.0
# Name: Thursday, dtype: object
#
#
# Friday
# ...

# %%
for i,j in dff.iterrows():
  print(i)
  print(j["Coffee Type"])
  print('\n')
# Out:
# Monday
# Espresso
#
#
# Monday
# Latte
#
#
# Tuesday
# Espresso
#
#
# Tuesday
# Latte
#
#
# Wednesday
# Espresso
#
#
# Wednesday
# Latte
#
#
# Thursday
# Espresso
#
#
# Thursday
# Latte
#
#
# Friday
# Espresso
#
#
# Friday
# Latte
#
#
# Saturday
# Espresso
#
#
# Saturday
# Latte
#
#
# Sunday
# Espresso
#
#
# Sunday
# Latte
#
#
# 1
# nan

# %% [markdown]
# #Filtering Data

# %%
dff.loc[dff['Units Sold']>20]
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        25.0
# Tuesday      Tuesday    Espresso        30.0
# Wednesday  Wednesday    Espresso        35.0
# Wednesday  Wednesday       Latte        25.0
# Thursday    Thursday    Espresso        40.0
# Thursday    Thursday       Latte        30.0
# Friday        Friday    Espresso        45.0
# Friday        Friday       Latte        35.0
# Saturday    Saturday    Espresso        45.0
# Saturday    Saturday       Latte        35.0
# Sunday        Sunday    Espresso        45.0
# Sunday        Sunday       Latte        35.0

# %%
dff[dff['Units Sold']>20]
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        25.0
# Tuesday      Tuesday    Espresso        30.0
# Wednesday  Wednesday    Espresso        35.0
# Wednesday  Wednesday       Latte        25.0
# Thursday    Thursday    Espresso        40.0
# Thursday    Thursday       Latte        30.0
# Friday        Friday    Espresso        45.0
# Friday        Friday       Latte        35.0
# Saturday    Saturday    Espresso        45.0
# Saturday    Saturday       Latte        35.0
# Sunday        Sunday    Espresso        45.0
# Sunday        Sunday       Latte        35.0

# %%
dff.loc[dff['Units Sold']>20,["Day","Coffee Type"]]
# Out:
#                  Day Coffee Type
# Day
# Monday        Monday    Espresso
# Tuesday      Tuesday    Espresso
# Wednesday  Wednesday    Espresso
# Wednesday  Wednesday       Latte
# Thursday    Thursday    Espresso
# Thursday    Thursday       Latte
# Friday        Friday    Espresso
# Friday        Friday       Latte
# Saturday    Saturday    Espresso
# Saturday    Saturday       Latte
# Sunday        Sunday    Espresso
# Sunday        Sunday       Latte

# %%
dff[(dff['Units Sold']>20) & (dff['Coffee Type']=='Espresso')]
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        25.0
# Tuesday      Tuesday    Espresso        30.0
# Wednesday  Wednesday    Espresso        35.0
# Thursday    Thursday    Espresso        40.0
# Friday        Friday    Espresso        45.0
# Saturday    Saturday    Espresso        45.0
# Sunday        Sunday    Espresso        45.0

# %%
dff[dff["Coffee Type"].str.contains("Espresso",case=False, na=False)]
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        25.0
# Tuesday      Tuesday    Espresso        30.0
# Wednesday  Wednesday    Espresso        35.0
# Thursday    Thursday    Espresso        40.0
# Friday        Friday    Espresso        45.0
# Saturday    Saturday    Espresso        45.0
# Sunday        Sunday    Espresso        45.0

# %%
dff[dff["Coffee Type"].str.contains("Espresso|Latte",case=False, na=False,regex=False)]
# Out:
# Empty DataFrame
# Columns: [Day, Coffee Type, Units Sold]
# Index: []

# %%
dff[dff["Day"].isin(["Monday","Friday"])]
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso        25.0
# Monday  Monday       Latte        15.0
# Friday  Friday    Espresso        45.0
# Friday  Friday       Latte        35.0

# %%
dff[(dff["Day"].isin(["Monday","Friday"])) & (dff['Coffee Type']==('Espresso'))]
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso        25.0
# Friday  Friday    Espresso        45.0

# %%
#dff.query('Coffee Type'=="Espresso")   Use backticks ` around column names with spaces like "Coffee Type".
dff.query('`Coffee Type` == "Espresso"')
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        25.0
# Tuesday      Tuesday    Espresso        30.0
# Wednesday  Wednesday    Espresso        35.0
# Thursday    Thursday    Espresso        40.0
# Friday        Friday    Espresso        45.0
# Saturday    Saturday    Espresso        45.0
# Sunday        Sunday    Espresso        45.0

# %% [markdown]
# # Add and Remove column

# %%
dff['price']=299
dff
# Out:
#           Day Coffee Type  Units Sold  new price  price
# 0      Monday    Espresso          25        250    299
# 1      Monday       Latte          15        299    299
# 2     Tuesday    Espresso          30        250    299
# 3     Tuesday       Latte          20        299    299
# 4   Wednesday    Espresso          35        250    299
# 5   Wednesday       Latte          25        299    299
# 6    Thursday    Espresso          40        250    299
# 7    Thursday       Latte          30        299    299
# 8      Friday    Espresso          45        250    299
# 9      Friday       Latte          35        299    299
# 10   Saturday    Espresso          45        250    299
# 11   Saturday       Latte          35        299    299
# 12     Sunday    Espresso          45        250    299
# 13     Sunday       Latte          35        299    299

# %%
import numpy as np
dff['new price']=np.where(dff['Coffee Type']=='Espresso',250,299)
dff
# Out:
#           Day Coffee Type  Units Sold  new price
# 0      Monday    Espresso          25        250
# 1      Monday       Latte          15        299
# 2     Tuesday    Espresso          30        250
# 3     Tuesday       Latte          20        299
# 4   Wednesday    Espresso          35        250
# 5   Wednesday       Latte          25        299
# 6    Thursday    Espresso          40        250
# 7    Thursday       Latte          30        299
# 8      Friday    Espresso          45        250
# 9      Friday       Latte          35        299
# 10   Saturday    Espresso          45        250
# 11   Saturday       Latte          35        299
# 12     Sunday    Espresso          45        250
# 13     Sunday       Latte          35        299

# %%
dff.drop(columns=['price'],inplace=True)
dff
# Out:
#           Day Coffee Type  Units Sold  new price
# 0      Monday    Espresso          25        250
# 1      Monday       Latte          15        299
# 2     Tuesday    Espresso          30        250
# 3     Tuesday       Latte          20        299
# 4   Wednesday    Espresso          35        250
# 5   Wednesday       Latte          25        299
# 6    Thursday    Espresso          40        250
# 7    Thursday       Latte          30        299
# 8      Friday    Espresso          45        250
# 9      Friday       Latte          35        299
# 10   Saturday    Espresso          45        250
# 11   Saturday       Latte          35        299
# 12     Sunday    Espresso          45        250
# 13     Sunday       Latte          35        299

# %%
coffee=dff.copy()
coffee['rating']=np.where(coffee['Units Sold']>20,'High','Low')
coffee
# Out:
#           Day Coffee Type  Units Sold  new price rating
# 0      Monday    Espresso          25        250   High
# 1      Monday       Latte          15        299    Low
# 2     Tuesday    Espresso          30        250   High
# 3     Tuesday       Latte          20        299    Low
# 4   Wednesday    Espresso          35        250   High
# 5   Wednesday       Latte          25        299   High
# 6    Thursday    Espresso          40        250   High
# 7    Thursday       Latte          30        299   High
# 8      Friday    Espresso          45        250   High
# 9      Friday       Latte          35        299   High
# 10   Saturday    Espresso          45        250   High
# 11   Saturday       Latte          35        299   High
# 12     Sunday    Espresso          45        250   High
# 13     Sunday       Latte          35        299   High

# %%
dff
# Out:
#           Day Coffee Type  Units Sold  new price
# 0      Monday    Espresso          25        250
# 1      Monday       Latte          15        299
# 2     Tuesday    Espresso          30        250
# 3     Tuesday       Latte          20        299
# 4   Wednesday    Espresso          35        250
# 5   Wednesday       Latte          25        299
# 6    Thursday    Espresso          40        250
# 7    Thursday       Latte          30        299
# 8      Friday    Espresso          45        250
# 9      Friday       Latte          35        299
# 10   Saturday    Espresso          45        250
# 11   Saturday       Latte          35        299
# 12     Sunday    Espresso          45        250
# 13     Sunday       Latte          35        299

# %%
coffee['revenue']=coffee['Units Sold']*coffee['new price']
coffee
# Out:
#           Day Coffee Type  Units Sold  new price rating  revenue
# 0      Monday    Espresso          25        250   High     6250
# 1      Monday       Latte          15        299    Low     4485
# 2     Tuesday    Espresso          30        250   High     7500
# 3     Tuesday       Latte          20        299    Low     5980
# 4   Wednesday    Espresso          35        250   High     8750
# 5   Wednesday       Latte          25        299   High     7475
# 6    Thursday    Espresso          40        250   High    10000
# 7    Thursday       Latte          30        299   High     8970
# 8      Friday    Espresso          45        250   High    11250
# 9      Friday       Latte          35        299   High    10465
# 10   Saturday    Espresso          45        250   High    11250
# 11   Saturday       Latte          35        299   High    10465
# 12     Sunday    Espresso          45        250   High    11250
# ...

# %%
coffee['price']=200

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new price rating  revenue  price
# 0      Monday    Espresso          25        250   High     6250    200
# 1      Monday       Latte          15        299    Low     4485    200
# 2     Tuesday    Espresso          30        250   High     7500    200
# 3     Tuesday       Latte          20        299    Low     5980    200
# 4   Wednesday    Espresso          35        250   High     8750    200
# 5   Wednesday       Latte          25        299   High     7475    200
# 6    Thursday    Espresso          40        250   High    10000    200
# 7    Thursday       Latte          30        299   High     8970    200
# 8      Friday    Espresso          45        250   High    11250    200
# 9      Friday       Latte          35        299   High    10465    200
# 10   Saturday    Espresso          45        250   High    11250    200
# 11   Saturday       Latte          35        299   High    10465    200
# ...

# %%
coffee.drop(columns=['price'],inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new price rating  revenue
# 0      Monday    Espresso          25        250   High     6250
# 1      Monday       Latte          15        299    Low     4485
# 2     Tuesday    Espresso          30        250   High     7500
# 3     Tuesday       Latte          20        299    Low     5980
# 4   Wednesday    Espresso          35        250   High     8750
# 5   Wednesday       Latte          25        299   High     7475
# 6    Thursday    Espresso          40        250   High    10000
# 7    Thursday       Latte          30        299   High     8970
# 8      Friday    Espresso          45        250   High    11250
# 9      Friday       Latte          35        299   High    10465
# 10   Saturday    Espresso          45        250   High    11250
# 11   Saturday       Latte          35        299   High    10465
# 12     Sunday    Espresso          45        250   High    11250
# ...

# %%
coffee.rename(columns={'new price':'price'},inplace=True)
coffee
# Out:
#           Day Coffee Type  Units Sold  price rating  revenue
# 0      Monday    Espresso          25    250   High     6250
# 1      Monday       Latte          15    299    Low     4485
# 2     Tuesday    Espresso          30    250   High     7500
# 3     Tuesday       Latte          20    299    Low     5980
# 4   Wednesday    Espresso          35    250   High     8750
# 5   Wednesday       Latte          25    299   High     7475
# 6    Thursday    Espresso          40    250   High    10000
# 7    Thursday       Latte          30    299   High     8970
# 8      Friday    Espresso          45    250   High    11250
# 9      Friday       Latte          35    299   High    10465
# 10   Saturday    Espresso          45    250   High    11250
# 11   Saturday       Latte          35    299   High    10465
# 12     Sunday    Espresso          45    250   High    11250
# 13     Sunday       Latte          35    299   High    10465

# %%
#To get first name
#bios_new =bios.copy()
#bios_new['first_name']=bios_new['name'].str.split(' ').str[0]
#bios_new.query('first_name=="Keith"')

# %%
#object type to date time
#bios_new['born_date']=pd.to_datetime(bios_new['born_date'])
#bios_new['born_year']=bios_new['born_date'].dt.year

#bios_new.to_csv('./data/bios_new.csv',index=False)

# %%
#bios_new['height_category']=bios_new['height_cm'].apply(lambda x: 'Short if x<165 else('Average' if x<185 else ]'Tall'))

# %%
'''
def categorize_athlete(row):
  if row['height_cm']<175 and row['weight_kg']<70:
    return 'LigthWeight'
  elif row['height_cm']<185 and row['weight_kg']<=80:
    return 'MiddleWeight'
  else:
    return 'HeavyWeight'

bios_new['athlete_category']=bios_new.apply(categorize_athlete,axis=1)
''
'''

# %% [markdown]
# #Merging and Concatenation

# %%
'''
new_bios=pd.merge(bios,nocs,left_on='born_country',right_on='NOC',how='left',suffixes=('_bios','_nocs')
new_bios.rename(columns={'region':'born_country_full'},inplace =True)
new_bios
'''

# %%
'''
combined_df=pd.merge(result,bios,on='athelete_id',how='left')
combined_df
'''
'''

# %%
'''
usa=bios[bios['born_country']=='USA'].copy()
gbr=bios[bios['born_country']=='GBR'].copy()

new_df=pd.concat([usa,gbr],ignore_index=True)
new_df
'''

# %% [markdown]
# #Handling null values

# %%
import pandas as pd
import numpy as np
coffee=pd.read_csv("/content/coffee.csv")

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.loc[[0,1],'Units Sold']=np.nan
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso         NaN
# 1     Monday       Latte         NaN
# 2    Tuesday    Espresso        30.0
# 3    Tuesday       Latte        20.0
# 4  Wednesday    Espresso        35.0

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# dtype: int64

# %%
coffee.loc[:,'Units Sold'].fillna(0,inplace=True)
coffee.head()
# Out:
# <ipython-input-16-450b6b24b581>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   coffee.loc[:,'Units Sold'].fillna(0,inplace=True)
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso         0.0
# 1     Monday       Latte         0.0
# 2    Tuesday    Espresso        30.0
# 3    Tuesday       Latte        20.0
# 4  Wednesday    Espresso        35.0

# %%
#or
coffee.fillna(100,inplace=True)
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso       100.0
# 1     Monday       Latte       100.0
# 2    Tuesday    Espresso        30.0
# 3    Tuesday       Latte        20.0
# 4  Wednesday    Espresso        35.0

# %%
#or
coffee.fillna(coffee['Units Sold'].mean(),inplace=True)
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso        35.0
# 1     Monday       Latte        35.0
# 2    Tuesday    Espresso        30.0
# 3    Tuesday       Latte        20.0
# 4  Wednesday    Espresso        35.0

# %%
#or
coffee.loc[[2,3],'Units Sold']=np.nan
coffee['Units Sold'].interpolate(method='linear',inplace=True)
coffee.head()
# Out:
# <ipython-input-23-08a17b46be06>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   coffee['Units Sold'].interpolate(method='linear',inplace=True)
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso        35.0
# 1     Monday       Latte        35.0
# 2    Tuesday    Espresso        35.0
# 3    Tuesday       Latte        35.0
# 4  Wednesday    Espresso        35.0

# %%
coffee.loc[[2,3],'Units Sold']=np.nan
coffee.dropna(inplace=True) #any row that has at least one NaN value in any column.


coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso        35.0
# 1     Monday       Latte        35.0
# 4  Wednesday    Espresso        35.0
# 5  Wednesday       Latte        25.0
# 6   Thursday    Espresso        40.0

# %%
#or
coffee.loc[[2,3],'Units Sold']=np.nan
coffee.dropna(subset=['Units Sold'],inplace=True) #Drops rows only if 'Units Sold' is missing.
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso        25.0
# 1     Monday       Latte        15.0
# 4  Wednesday    Espresso        35.0
# 5  Wednesday       Latte        25.0
# 6   Thursday    Espresso        40.0

# %%
coffee.loc[[2,3],'Units Sold']=np.nan
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso        25.0
# 1      Monday       Latte        15.0
# 4   Wednesday    Espresso        35.0
# 5   Wednesday       Latte        25.0
# 6    Thursday    Espresso        40.0
# 7    Thursday       Latte        30.0
# 8      Friday    Espresso        45.0
# 9      Friday       Latte        35.0
# 10   Saturday    Espresso        45.0
# 11   Saturday       Latte        35.0
# 12     Sunday    Espresso        45.0
# 13     Sunday       Latte        35.0

# %%
coffee[coffee['Units Sold'].isna()]
# Out:
#        Day Coffee Type  Units Sold
# 2  Tuesday    Espresso         NaN
# 3  Tuesday       Latte         NaN

# %% [markdown]
# #Aggregating Data

# %%
coffee['Coffee Type'].value_counts()
# Out:
# Coffee Type
# Espresso    7
# Latte       7
# Name: count, dtype: int64

# %%
coffee['Units Sold'].value_counts()
# Out:
# Units Sold
# 35.0    4
# 45.0    3
# 25.0    2
# 15.0    1
# 40.0    1
# 30.0    1
# Name: count, dtype: int64

# %%
bios=pd.read_excel('/content/olympics-data.xlsx')
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios[bios['born_country']=='USA']['born_region'].value_counts().tail()
# Out:
# born_region
# South Dakota     27
# West Virginia    24
# Delaware         22
# North Dakota     16
# Wyoming          14
# Name: count, dtype: int64

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    265
# Latte       195
# Name: Units Sold, dtype: int64

# %%
coffee['price']=np.where(coffee['Coffee Type']=='Espresso',250,299)

# %%
coffee['revenue']=coffee['Units Sold']*coffee['price']

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold':'sum','price':'mean'})
# Out:
#              Units Sold  price
# Coffee Type
# Espresso            265  250.0
# Latte               195  299.0

# %%
pivot=coffee.pivot_table(index='Day',columns='Coffee Type',values='revenue')
pivot
# Out:
# Coffee Type  Espresso    Latte
# Day
# Friday        11250.0  10465.0
# Monday         6250.0   4485.0
# Saturday      11250.0  10465.0
# Sunday        11250.0  10465.0
# Thursday      10000.0   8970.0
# Tuesday        7500.0   5980.0
# Wednesday      8750.0   7475.0

# %%
pivot.loc['Monday','Latte']
# Out:
# np.float64(4485.0)

# %%
pivot.sum()
# Out:
# Coffee Type
# Espresso    66250.0
# Latte       58305.0
# dtype: float64

# %%
pivot.sum(axis=1)
# Out:
# Day
# Friday       21715.0
# Monday       10735.0
# Saturday     21715.0
# Sunday       21715.0
# Thursday     18970.0
# Tuesday      13480.0
# Wednesday    16225.0
# dtype: float64

# %%
bios['born_date']=pd.to_datetime(bios['born_date'])
bios['born_year']=bios['born_date'].dt.year

# %%
bios.groupby(bios['born_date'].dt.year)['name'].count()
# Out:
# born_date
# 1828.0      1
# 1831.0      2
# 1833.0      1
# 1836.0      1
# 1837.0      1
#          ...
# 2005.0    163
# 2006.0     17
# 2007.0      3
# 2008.0      3
# 2009.0      1
# Name: name, Length: 177, dtype: int64

# %%
bios.groupby(bios['born_date'].dt.year)['name'].count().reset_index().sort_values('name',ascending=False)
# Out:
#      born_date  name
# 139     1972.0  2231
# 152     1985.0  2227
# 140     1973.0  2216
# 138     1971.0  2205
# 137     1970.0  2174
# ..         ...   ...
# 4       1837.0     1
# 2       1833.0     1
# 6       1839.0     1
# 12      1845.0     1
# 176     2009.0     1
#
# [177 rows x 2 columns]

# %%
coffee['YesterdayRevenue']=coffee['revenue'].shift(2)
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  YesterdayRevenue
# 0      Monday    Espresso          25    250     6250               NaN
# 1      Monday       Latte          15    299     4485               NaN
# 2     Tuesday    Espresso          30    250     7500            6250.0
# 3     Tuesday       Latte          20    299     5980            4485.0
# 4   Wednesday    Espresso          35    250     8750            7500.0
# 5   Wednesday       Latte          25    299     7475            5980.0
# 6    Thursday    Espresso          40    250    10000            8750.0
# 7    Thursday       Latte          30    299     8970            7475.0
# 8      Friday    Espresso          45    250    11250           10000.0
# 9      Friday       Latte          35    299    10465            8970.0
# 10   Saturday    Espresso          45    250    11250           11250.0
# 11   Saturday       Latte          35    299    10465           10465.0
# ...

# %%
coffee['pct_change']=coffee['revenue']/coffee['YesterdayRevenue']*100
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  YesterdayRevenue  \
# 0      Monday    Espresso          25    250     6250               NaN
# 1      Monday       Latte          15    299     4485               NaN
# 2     Tuesday    Espresso          30    250     7500            6250.0
# 3     Tuesday       Latte          20    299     5980            4485.0
# 4   Wednesday    Espresso          35    250     8750            7500.0
# 5   Wednesday       Latte          25    299     7475            5980.0
# 6    Thursday    Espresso          40    250    10000            8750.0
# 7    Thursday       Latte          30    299     8970            7475.0
# 8      Friday    Espresso          45    250    11250           10000.0
# 9      Friday       Latte          35    299    10465            8970.0
# 10   Saturday    Espresso          45    250    11250           11250.0
# 11   Saturday       Latte          35    299    10465           10465.0
# ...

# %%
bios['height_rank']=bios['height_cm'].rank()
bios
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         André Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.sort_values(['height_rank']).sample(10)
# Out:
#        athlete_id                 name  born_date  born_city      born_region  \
# 23650       23834        Edmundo López 1935-08-13        NaN              NaN
# 47654       48006       Blanca Morales 1970-02-03        NaN              NaN
# 54981       55376             Li Jinhe 1964-05-22    Linqing         Shandong
# 67286       67797      Pauli Sandström 1899-12-25      Turku  Varsinais-Suomi
# 56519       56922         David Rigert 1947-03-12  Nagornoye           Aqmola
# 44397       44738           Tommy Pool 1935-02-10      Bowie            Texas
# 22593       22763        Harunobu Deno 1969-08-28        NaN              NaN
# 55753       56149     Silvio Quadrelli 1889-04-09     Milano           Milano
# 33236       33488         Alex Bijkerk 1947-09-13        NaN              NaN
# 66227       66732  Bárbara Hechevarría 1966-08-06    Holguín          Holguín
#
#       born_country                         NOC  height_cm  weight_kg  \
# ...

# %%
bios.sort_values(['height_rank']).sample(10)[['name','height_rank']]
# Out:
#                         name  height_rank
# 85888             Peter Heli      29614.5
# 26884   Sultan Waleed Jamaan      36671.5
# 49660            Jackie Wiid          NaN
# 35633      Zdravka Yordanova      22677.0
# 33566       Alonzo Henderson      59686.0
# 71987        Masaki Morinaga      48271.5
# 17557        Charles Guiette          NaN
# 112817             Wang Ying      88530.0
# 135718        Liviu Hanganut          NaN
# 105694    Barry Kirk Jackman     103481.5

# %%
coffee['cumulative_revenue']=coffee['revenue'].cumsum()
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  YesterdayRevenue  \
# 0      Monday    Espresso          25    250     6250               NaN
# 1      Monday       Latte          15    299     4485               NaN
# 2     Tuesday    Espresso          30    250     7500            6250.0
# 3     Tuesday       Latte          20    299     5980            4485.0
# 4   Wednesday    Espresso          35    250     8750            7500.0
# 5   Wednesday       Latte          25    299     7475            5980.0
# 6    Thursday    Espresso          40    250    10000            8750.0
# 7    Thursday       Latte          30    299     8970            7475.0
# 8      Friday    Espresso          45    250    11250           10000.0
# 9      Friday       Latte          35    299    10465            8970.0
# 10   Saturday    Espresso          45    250    11250           11250.0
# 11   Saturday       Latte          35    299    10465           10465.0
# ...

# %%
latte=coffee[coffee['Coffee Type']=='Latte'].copy()
latte['3day']=latte['Units Sold'].rolling(3).sum()
latte
# Out:
#           Day Coffee Type  Units Sold  price  revenue  YesterdayRevenue  \
# 1      Monday       Latte          15    299     4485               NaN
# 3     Tuesday       Latte          20    299     5980            4485.0
# 5   Wednesday       Latte          25    299     7475            5980.0
# 7    Thursday       Latte          30    299     8970            7475.0
# 9      Friday       Latte          35    299    10465            8970.0
# 11   Saturday       Latte          35    299    10465           10465.0
# 13     Sunday       Latte          35    299    10465           10465.0
#
#     pct_change  cumulative_revenue   3day
# 1          NaN               10735    NaN
# 3   133.333333               24215    NaN
# 5   125.000000               40440   60.0
# 7   120.000000               59410   75.0
# 9   116.666667               81125   90.0
# 11  100.000000              102840  100.0
# 13  100.000000              124555  105.0

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
coffee['Day'].str.contains('Monday').head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: Day, dtype: bool
